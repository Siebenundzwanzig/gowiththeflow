# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
sample_size = 30
np.random.seed(1)
cats = np.random.normal(25,5,(2,sample_size))
dogs = np.random.normal(45,15,(2,sample_size))
y_hat_cats = 0
y_hat_dog = 1


plt.subplot(211)
plt.title('Training Data')
plt.xlabel('Length')
plt.ylabel('Height')
plt.plot(cats[0],cats[1],'bo')
plt.plot(dogs[0],dogs[1],'yo')


cats_norm = (cats - 25) 

dogs_norm = (dogs - 45)
print(dogs_norm)

plt.subplot(212)
plt.title('Normalized Training Data')
plt.xlabel('Length')
plt.ylabel('Height')
plt.plot(cats_norm[0],cats_norm[1],'bo')
plt.plot(dogs_norm[0],dogs_norm[1],'yo')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.2857251726853">
# [[-11.31596911  18.79302233   7.69394731  -4.47139253   7.3277722
#    -1.1335757   16.97444081  22.79725225  32.7836311  -20.94744503
#   -21.66170708  -7.56698794   2.40055604  13.14253382   4.73452421
#   -30.33301824  -4.59306019  12.41961964   3.45142103  11.4301677
#    -3.33492214  -3.01137103   2.79842086   6.15077471   2.9744958
#     1.78512969 -10.05993429   5.66345679   1.82731906  16.94225862]
#  [ 17.9837682    2.77734626  -5.62927425  -9.58095611   6.35241531
#     1.16010103  -5.15780513   0.65395285  -9.30001266  10.47048051
#    -6.70692847  18.36761557   6.05237463   8.90367785 -16.42367769
#     2.5407365   11.10834677 -14.30550903  -3.99327759   0.4892182
#   -20.5967598    4.72739088  12.69240971 -12.89273911   5.25818968
#   -19.68425117  -0.58043264 -24.23658532  16.82126562   6.13350807]]

# %%
learning_rate = 0.1
weights = ([-2.5,-2.5])



    
def batching(batch_size):
    
    dic = {'vector': np.zeros((batch_size, 2)), 'labels': np.array([])}
    for x in range(batch_size):
        cat_or_dog = np.random.randint(0, 2)
    
        if cat_or_dog == 0:
            random = np.random.randint(0, 30)
            dic['vector'][x][0] = cats[0][random]
            dic['vector'][x][1] = cats[1][random]
            
        elif cat_or_dog == 1:
            random = np.random.randint(0, 30)
            dic['vector'][x][0] = dogs[0][random]
            dic['vector'][x][1] = dogs[1][random]
                                      
        dic['labels'] = np.append(dic['labels'], cat_or_dog)
        
    return dic
    
    

def forward(batch_size):
    
    dataset = batching(batch_size)
    print('dot: ', np.dot(dataset['vector'],weights))
    y = activation(np.dot(dataset['vector'],weights))
    print('y: ', y)
    ylabels = dataset['labels']
    
    return y, ylabels, dataset


def activation(x):
    return 1/(1+np.exp(-x))


def loss(batch_size):
    
    y, ylabels, dataset = forward(batch_size)
#    l = 0
#   l += 0.5*((ylabels-y)**2)
#    return l, 

    error = ylabels - y
    return error, y, dataset

def function(x, derive = False):
    
    if(derive==True):
        2*x
    print('x: ' , x)
    return np.square(x)
    
    
for training_step in range(20):
    error, y, dataset = loss(1)
    l1_delta = error * function(y, derive=True)
    print(error)
    weights += np.dot(dataset['vector'].T, l1_delta)
    print(l1_delta)
print(weights)

#    weights[0] = weights[0] - learning_rate * function(loss(20), True)
#    weights[1] = weights[1] - learning_rate * function(loss(20), True)

#lo, dataset = loss(50)
#delta = lo * function(dataset['vector'], True)
# Out:
# dot:  [-112.39362574]
# y:  [  1.54194378e-49]
# x:  [  1.54194378e-49]
# [ -1.54194378e-49]
# [ -3.66611104e-147]
# dot:  [-254.79846476]
# y:  [  2.20005104e-111]
# x:  [  2.20005104e-111]
# [ 1.]
# [  4.84022457e-222]
# dot:  [-134.90592329]
# y:  [  2.57692595e-59]
# x:  [  2.57692595e-59]
# [ -2.57692595e-59]
# [ -1.71121987e-176]
# dot:  [-246.13232667]
# y:  [  1.27669956e-107]
# x:  [  1.27669956e-107]
# [ 1.]
# [  1.62996177e-214]
# dot:  [-127.02965874]
# y:  [  6.78766143e-56]
# x:  [  6.78766143e-56]
# [ -6.78766143e-56]
# [ -3.12723497e-166]
# dot:  [-229.29004962]
# y:  [  2.63388432e-100]
# x:  [  2.63388432e-100]
# [ 1.]
# [  6.93734659e-200]
# dot:  [-96.0724588]
# y:  [  1.88912754e-42]
# x:  [  1.88912754e-42]
# [ -1.88912754e-42]
# [ -6.74192377e-126]
# dot:  [-178.56717869]
# y:  [  2.81358246e-78]
# x:  [  2.81358246e-78]
# [ 1.]
# [  7.91624625e-156]
# dot:  [-225.06631332]
# y:  [  1.79863094e-98]
# x:  [  1.79863094e-98]
# [ 1.]
# [  3.23507327e-196]
# ...
