# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
sample_size = 30
np.random.seed(1)
cats = np.random.normal(25,5,(2,sample_size))
dogs = np.random.normal(45,15,(2,sample_size))


plt.subplot(211)
plt.title('Training Data')
plt.xlabel('Lenght')
plt.ylabel('Height')
plt.plot(cats[0],cats[1],'bo')
plt.plot(dogs[0],dogs[1],'yo')

cats_norm = (cats-5)/25
dogs_norm = (dogs-5)/25

plt.subplot(212)
plt.title('Normalized Training Data')
plt.xlabel('Lenght')
plt.ylabel('Height')
plt.plot(cats_norm[0],cats_norm[1],'bo')
plt.plot(dogs_norm[0],dogs_norm[1],'yo')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
class Network(object):
    def _init_(self):
        self.inputLayerSize = 2
        self.outputLayerSize = 1
        self.hiddenLayerSize = 1

#activation function
def actLog(x):
    return 1/(1+np.exp(-x))

def batching(array, batch_size):
    batch = np.array([],[])
    for x in range(batch_size):
        random = np.random.randnm(0,sample_size-1)
        np.append(batch[0], array[0,random])
        np.append(batch[1], array[1,random])
    return batch
    
    
weights = np.array([-2.5,-2.5])


def forward(array, weights):
    
    y_hat = np.array([])
    for r in range(sample_size):
        y_hat = np.append(y_hat,np.dot((array[0,r],array[1,r]),weights))
        
    return y_hat


#all at once
#y_hat = np.array([])
#for r in range(sample_size):
#    np.append(y_hat,np.dot((cats[0,r],cats[1,r]),weights))
    
print(forward(cats,weights))
# Out:
# [-136.65855765 -112.39362574 -109.80819435 -101.0228217  -127.42701873
#   -96.0724588  -132.84376769 -118.41510996 -149.73551591 -131.15842231
#  -140.87840481  -88.15287908 -111.63030628 -141.35500308 -139.80721496
#  -103.28891358 -125.23109096 -140.27995898 -127.02965874 -140.00022904
#  -114.99438928 -134.90592329 -121.98840653 -126.91439521 -133.64952145
#  -123.78619165 -133.95116485 -124.94165809 -125.22124057 -142.69370789]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-72d3bee2dbe1> in <module>()
#       1 a = np.array([0,1,2,3,4,5,6,7])
# ----> 2 print(a[0, 1])
#
# IndexError: too many indices for array
